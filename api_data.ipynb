# %%
import requests
import pandas as pd

# %%
city_info = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv")
city_info.head()
# Out:
#          City           State  Population        lat         lon
# 0  Marysville      Washington       63269  48.051764 -122.177082
# 1      Perris      California       72326  33.782519 -117.228648
# 2   Cleveland            Ohio      390113  41.499320  -81.694361
# 3   Worcester   Massachusetts      182544  42.262593  -71.802293
# 4    Columbia  South Carolina      133358  34.000710  -81.034814

# %%
city_info = city_info[city_info['Population'] > 100000]

# %%
city_info.loc[191:]
# Out:
#                      City       State  Population        lat         lon
# 191           Albuquerque  New Mexico      556495  35.085334 -106.605553
# 192  Athens-Clarke County     Georgia      119980  33.951935  -83.357567
# 194       North Las Vegas      Nevada      226877  36.198859 -115.117501
# 195                Pomona  California      151348  34.055103 -117.749991
# 199               Midland       Texas      123933  31.997346 -102.077915
# ..                    ...         ...         ...        ...         ...
# 980              Glendale     Arizona      234632  33.538652 -112.185987
# 983             Davenport        Iowa      102157  41.523644  -90.577637
# 988               Gresham      Oregon      109397  45.500136 -122.430201
# 991           Santa Clara  California      120245  37.354108 -121.955236
# 992             Oceanside  California      172794  33.195870 -117.379483
#
# [230 rows x 5 columns]

# %%
health_factors = ['air-pollution-particulate-matter', 'air-pollution-ozone', 'cardiovascular-disease-deaths', 'diabetes', 'frequent-mental-distress', 'obesity', 'physical-inactivity', 'walkability']

# %%
# data = []
for i, row in city_info.loc[1:].iterrows():
    for factor in health_factors:
        req = requests.get(f"https://api.cityhealthdashboard.com/api/data/city-metric/{factor}?token=47ebc17d73896e342294b8eb89783f47&city_name={row['City']}")
        if (req.status_code == 200) and ('error' not in req.json()):
            data.append(req.json()['rows'][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/kn/65gns3dx5651dx7dw03j_xjm0000gn/T/ipykernel_98176/787052273.py in <module>
#       4         req = requests.get(f"https://api.cityhealthdashboard.com/api/data/city-metric/{factor}?token=47ebc17d73896e342294b8eb89783f47&city_name={row['City']}")
#       5         if (req.status_code == 200) and ('error' not in req.json()):
# ----> 6             data.append(req.json()['rows'][0])
#
# IndexError: list index out of range

# %%
pd.DataFrame(data=data)
# Out:
#     state_abbr state_fips place_fips stpl_fips    city_name  \
# 0           WA         53      43955   5343955   Marysville
# 1           WA         53      43955   5343955   Marysville
# 2           WA         53      43955   5343955   Marysville
# 3           WA         53      43955   5343955   Marysville
# 4           WA         53      43955   5343955   Marysville
# ..         ...        ...        ...       ...          ...
# 541         NM         35      02000   3502000  Albuquerque
# 542         NM         35      02000   3502000  Albuquerque
# 543         NM         35      02000   3502000  Albuquerque
# 544         NM         35      02000   3502000  Albuquerque
# 545         NM         35      02000   3502000  Albuquerque
#
#                             metric_name  metric_number        group_name  \
# 0    Air pollution - particulate matter              2  total population
# 1         Cardiovascular disease deaths             29             asian
# 2                              Diabetes              6  total population
# 3              Frequent mental distress              7  total population
# 4                               Obesity             17  total population
# ..                                  ...            ...               ...
# 541                            Diabetes              6  total population
# 542            Frequent mental distress              7  total population
# 543                             Obesity             17  total population
# 544                 Physical inactivity             18  total population
# 545                         Walkability             27  total population
#
#      group_number  num  denom   est    lci    uci  county_indicator  \
# 0               1 -999   -999   7.4 -999.0 -999.0            -999.0
# 1               4 -999   -999   NaN    NaN    NaN               NaN
# 2               1 -999   -999   8.9    8.7    9.1            -999.0
# 3               1 -999   -999  13.7   13.4   14.0            -999.0
# 4               1 -999   -999  32.4   32.1   32.7            -999.0
# ..            ...  ...    ...   ...    ...    ...               ...
# 541             1 -999   -999  10.1   10.1   10.1            -999.0
# 542             1 -999   -999  14.4   14.3   14.5            -999.0
# 543             1 -999   -999  27.1   27.0   27.2            -999.0
# 544             1 -999   -999  18.8   18.6   19.0            -999.0
# 545             1 -999   -999  41.6 -999.0 -999.0            -999.0
#
#      multiplier_indicator                   data_yr_type geo_level  \
# 0                    -999                           2017      city
# 1                       3          2017, 3 Year Estimate      city
# 2                    -999  2018, 1 Year Modeled Estimate      city
# 3                    -999  2018, 1 Year Modeled Estimate      city
# 4                    -999  2018, 1 Year Modeled Estimate      city
# ..                    ...                            ...       ...
# 541                  -999  2018, 1 Year Modeled Estimate      city
# 542                  -999  2018, 1 Year Modeled Estimate      city
# 543                  -999  2018, 1 Year Modeled Estimate      city
# 544                  -999  2018, 1 Year Modeled Estimate      city
# 545                  -999                           2019      city
#
#               date_export
# 0    2022-01-11T00:00:00Z
# 1    2022-01-11T00:00:00Z
# 2    2022-01-11T00:00:00Z
# 3    2022-01-11T00:00:00Z
# 4    2022-01-11T00:00:00Z
# ..                    ...
# 541  2022-01-11T00:00:00Z
# 542  2022-01-11T00:00:00Z
# 543  2022-01-11T00:00:00Z
# 544  2022-01-11T00:00:00Z
# 545  2022-01-11T00:00:00Z
#
# [546 rows x 19 columns]

# %%
all_health_data = pd.read_csv('/Users/kenthansen/Projects/All CHDB Cities v13.1 - released January 11, 2022/CHDB_data_city_all_v13.1.csv')
all_health_data.head()
# Out:
# /Users/kenthansen/miniconda3/envs/geo_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   state_abbr  state_fips  place_fips  stpl_fips city_name  metric_name  \
# 0         AL           1        3076     103076    Auburn  Absenteeism
# 1         AL           1        3076     103076    Auburn  Absenteeism
# 2         AL           1        3076     103076    Auburn  Absenteeism
# 3         AL           1        3076     103076    Auburn  Absenteeism
# 4         AL           1        3076     103076    Auburn  Absenteeism
#
#    metric_number group_name  group_number    num  ...    lci    uci  \
# 0              1      asian             4    NaN  ... -999.0 -999.0
# 1              1      black             5  163.0  ... -999.0 -999.0
# 2              1     female             2  237.0  ... -999.0 -999.0
# 3              1   hispanic             6   41.0  ... -999.0 -999.0
# 4              1       male             3  225.0  ... -999.0 -999.0
#
#    county_indicator  multiplier_indicator  data_yr_type  date_export  \
# 0            -999.0                  -999     2017-2018   2022-01-11
# 1            -999.0                  -999     2017-2018   2022-01-11
# 2            -999.0                  -999     2017-2018   2022-01-11
# 3            -999.0                  -999     2017-2018   2022-01-11
# 4            -999.0                  -999     2017-2018   2022-01-11
#
#   geo_level version                                    NCHS_disclaimer  \
# 0      city    13.1  The downloadable data tables shared on the Cit...
# 1      city    13.1                                                NaN
# 2      city    13.1                                                NaN
# 3      city    13.1                                                NaN
# 4      city    13.1                                                NaN
#
#                                   suggested_citation
# 0  Department of Population Health, NYU Langone H...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 22 columns]

# %%
health_factors = ['Air pollution - particulate matter', 'Air pollution - ozone', 'Cardiovascular disease deaths', 'Diabetes', 'Frequent mental distress', 'Obesity', 'Physical inactivity', 'Walkability']

# %%
filtered_health = all_health_data[all_health_data['metric_name'].isin(health_factors)]

# %%
filtered_health = filtered_health[['state_abbr', 'city_name', 'metric_name', 'group_name', 'est']]

# %%
city_info.columns = ['city_name', 'state', 'population', 'lat', 'lon']

# %%
filtered_health = filtered_health.reset_index()
city_info = city_info.reset_index()

# %%
filtered_health = filtered_health.drop('index', axis=1)
city_info = city_info.drop('index', axis=1)

# %%
filtered_health = filtered_health.set_index('city_name')
city_info = city_info.set_index('city_name')

# %%
joined = filtered_health.join(city_info, on='city_name')

# %%
joined = joined.dropna()

# %%
joined.to_csv('db_data.csv')
